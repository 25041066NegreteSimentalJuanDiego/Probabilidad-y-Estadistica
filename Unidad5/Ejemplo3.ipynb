# %% [markdown]
# <a href="https://colab.research.google.com/github/25041066NegreteSimentalJuanDiego/Probabilidad-y-Estadistica/blob/main/Unidad5/Ejemplo3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Probabilidad y Estadistica
# ##Unidad 5
# ###Ejemplo 2
# ###Docente: Dr Jose Gabriel Rodriguez Rivas
# ###Alumno: Juan Diego Negrete Simental

# %%
from scipy.stats import pearsonr
#Datos de entrada
publicidad = [2, 3, 5, 4, 11, 5]
ganancias = [20, 25, 34, 30, 40, 31]

#Calcular el coeficiente de correlacion de Pearson
coeficiente_correlacion, p_valor = pearsonr(publicidad, ganancias)

print("Coeficiente de correlacion de Pearson:", coeficiente_correlacion)
print("Valor p:", p_valor)
# Out:
# Coeficiente de correlacion de Pearson: 0.909090909090909
# Valor p: 0.012021036814425281
