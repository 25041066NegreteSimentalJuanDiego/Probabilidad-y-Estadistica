# %% [markdown]
# <a href="https://colab.research.google.com/github/25041066NegreteSimentalJuanDiego/Probabilidad-y-Estadistica/blob/main/Unidad5/Ejemplo1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Probabilidad y Estadistica
# ##Unidad 5
# ###Ejemplo 1
# ###Docente: Dr Jose Gabriel Rodriguez Rivas
# ###Alumno: Juan Diego Negrete Simental

# %%
from sklearn.linear_model import LinearRegression  # Modelo de regresión Lineal
import numpy as np

# Datos de entrada
periodos = [2018, 2019, 2020, 2021, 2022, 2023]
inversion = np.array([2, 3, 5, 4, 11, 5]).reshape(-1, 1)
ganancias = [20, 25, 34, 30, 40, 31]

# Crear y entrenar el modelo de regresión lineal
modelo = LinearRegression()
modelo.fit(inversion, ganancias)

# Predecir la ganancia para el año 2024
ganancia_2024 = modelo.predict([[8]])

print("La ganancia esperada para el año 2024 es de:", ganancia_2024[0])

# Coeficientes de la regresión
print("Coeficiente de la pendiente (m):", modelo.coef_[0])
print("Intercepcion de la recta (b):", modelo.intercept_)
# Out:
# La ganancia esperada para el año 2024 es de: 36.0
# Coeficiente de la pendiente (m): 2.0000000000000004
# Intercepcion de la recta (b): 20.0

# %%
import matplotlib.pyplot as plt
import seaborn as sns

#Definir tamaño de la figura
plt.figure(figsize=(6,4))

#Datos de entrada
inversion = [2, 3, 5, 4, 11, 5]
ganancias = [20, 25, 34, 30, 40, 31]

#Dibujar el diagrama de dispersion
sns.scatterplot(x=inversion, y=ganancias)
plt.title('Diagrama de Dispercion de Inversion vs Ganancias')
plt.xlabel('Inversion (millones)')
plt.ylabel('Ganancia (Millones)')
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

#Definir tamaño de la figura
plt.figure(figsize=(6,4))

#Datos de entrada
inversion = [2, 3, 5, 4, 11, 5]
ganancias = [20, 25, 34, 30, 40, 31]

#Dibujar el diagrama de dispersion con linea de regresion
sns.set(style="whitegrid")
sns.regplot(x=inversion, y=ganancias, scatter=True, color='blue')
plt.title('Diagrama de Dispercion de Inversion vs Ganancias')
plt.xlabel('Inversion (millones)')
plt.ylabel('Ganancia (Millones)')
plt.grid(True)
plt.show()
