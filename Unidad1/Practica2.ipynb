# %% [markdown]
# <a href="https://colab.research.google.com/github/25041066NegreteSimentalJuanDiego/Probabilidad-y-Estadistica/blob/main/Unidad1/Practica2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #PROBABILIDAD Y ESTADISTICA
# ##Unidad 1
# ###Máximo, mínimo, Rango y dispersión de datos.
# ###Facilitador: Jose Gabriel Rodriguez Rivas
# ###Negrete Simental Juan Diego

# %%
import random
import matplotlib.pyplot as plt
from statistics import *

# %%
#generamos 100 numeros aleatorios que representan la produccion
#en metros de tela de 100 dias
fabrica1=[]
for i in range (100):
  numero_aleatorio=round (random.uniform(0,100),2)
  fabrica1.append(numero_aleatorio)
print(fabrica1)
# Out:
# [35.04, 44.43, 13.49, 53.25, 76.36, 4.51, 29.28, 52.88, 35.41, 60.75, 35.85, 13.87, 28.91, 4.47, 21.6, 99.36, 59.57, 70.01, 27.7, 74.42, 62.53, 63.68, 28.98, 65.51, 72.99, 67.83, 26.47, 12.26, 87.6, 79.23, 28.34, 11.23, 96.39, 17.67, 81.52, 78.49, 95.2, 65.07, 73.02, 59.99, 10.53, 56.7, 82.09, 1.63, 34.18, 4.84, 11.56, 20.79, 46.53, 96.05, 22.95, 42.61, 98.57, 95.95, 94.33, 79.29, 34.98, 99.12, 41.44, 94.85, 11.34, 85.1, 38.84, 24.85, 36.71, 62.2, 75.56, 97.68, 25.12, 49.28, 74.71, 12.46, 58.85, 2.03, 6.52, 95.29, 40.22, 68.83, 4.13, 2.19, 57.3, 59.23, 13.04, 61.3, 89.47, 58.55, 12.57, 62.91, 39.74, 59.22, 18.21, 23.48, 36.89, 37.56, 95.08, 0.84, 38.95, 93.01, 72.49, 87.89]

# %%
fabrica2=[]
for i in range (100):
  numero_aleatorio=round (random.uniform(0,100),2)
  fabrica2.append(numero_aleatorio)
print(fabrica2)
# Out:
# [22.97, 72.25, 30.87, 79.89, 52.58, 98.15, 9.91, 44.38, 7.63, 94.39, 84.91, 76.86, 29.35, 28.71, 57.37, 46.64, 10.65, 10.9, 40.1, 14.41, 27.36, 4.81, 1.91, 85.36, 67.78, 70.83, 17.62, 21.71, 82.49, 74.3, 71.58, 89.03, 7.96, 16.15, 67.96, 74.86, 11.38, 18.04, 54.36, 28.63, 66.61, 44.5, 19.98, 84.75, 10.37, 91.03, 42.31, 67.58, 56.2, 5.02, 47.22, 72.73, 81.22, 83.48, 52.92, 39.93, 4.12, 43.92, 36.81, 48.53, 21.33, 7.69, 29.3, 38.28, 45.12, 17.52, 53.65, 79.95, 74.98, 24.06, 28.0, 61.37, 25.37, 19.53, 3.5, 51.13, 51.23, 89.79, 47.49, 62.12, 31.69, 40.6, 26.95, 4.15, 71.8, 59.08, 6.13, 91.53, 26.68, 26.59, 85.92, 33.55, 18.7, 99.14, 54.27, 6.21, 59.5, 38.54, 50.84, 48.35]

# %%
maximo1=max(fabrica1)
minimo1=min(fabrica1)
rango1=maximo1-minimo1
media1=mean(fabrica1)
mediana1=median(fabrica1)
moda1=mode(fabrica1)
desviacion_estandar_fabrica1=stdev(fabrica1)
print("Estadistica Descriptiva de la fabrica 1 \n","Media: ",media1,"\n Mediana: ",mediana1,"\n moda: ",moda1,"\n Maxino: ",maximo1,"\n Minimo: ",minimo1,"\n Rango: ",rango1)
print(desviacion_estandar_fabrica1)
# Out:
# Estadistica Descriptiva de la fabrica 1
#  Media:  49.7379
#  Mediana:  51.08
#  moda:  35.04
#  Maxino:  99.36
#  Minimo:  0.84
#  Rango:  98.52
# 30.227452045477076

# %%
maximo2=max(fabrica2)
minimo2=min(fabrica2)
rango2=maximo2-minimo2
media2=mean(fabrica2)
mediana2=median(fabrica2)
moda2=mode(fabrica2)
desviacion_estandar_fabrica2=stdev(fabrica2)
print("Estadistica Descriptiva de la fabrica 2 \n","Media: ",media2,"\n Mediana: ",mediana2,"\n moda: ",moda2,"\n Maxino: ",maximo2,"\n Minimo: ",minimo2,"\n Rango: ",rango2)
print(desviacion_estandar_fabrica2)
# Out:
# Estadistica Descriptiva de la fabrica 2
#  Media:  45.179
#  Mediana:  44.44
#  moda:  22.97
#  Maxino:  99.14
#  Minimo:  1.91
#  Rango:  97.23
# 27.62379312231842

# %%
plt.figure(figsize=(8,6))
plt.hist(fabrica1,bins=10,alpha=0.2,color='b',edgecolor="Black")
plt.axvline(media1,color='b',linestyle='dashed',linewidth=2,label=f'Media={media1:.2f}')
plt.axvline(mediana1,color='r',linestyle='dashed',linewidth=2,label=f'Mediana={mediana1:.2f}')
plt.axvline(moda1,color='y',linestyle='dashed',linewidth=2,label=f'Moda={moda1:.2f}')
plt.axvline(media1-desviacion_estandar_fabrica1,color='Black',linestyle='dashed',linewidth=2,label=f'desv. Estandar={desviacion_estandar_fabrica1:.2f}')
plt.axvline(media1+desviacion_estandar_fabrica1,color='Black',linestyle='dashed',linewidth=2)
plt.xlabel('valor')
plt.ylabel('Frecuencia')
plt.title('Produccion diaria de la fabrica 1')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(8,6))
plt.hist(fabrica2,bins=10,alpha=0.2,color='b',edgecolor="Black")
plt.axvline(media2,color='b',linestyle='dashed',linewidth=2,label=f'Media={media2:.2f}')
plt.axvline(mediana2,color='r',linestyle='dashed',linewidth=2,label=f'Mediana={mediana2:.2f}')
plt.axvline(moda2,color='y',linestyle='dashed',linewidth=2,label=f'Moda={moda2:.2f}')
plt.axvline(media2-desviacion_estandar_fabrica2,color='Black',linestyle='dashed',linewidth=2,label=f'desv. Estandar={desviacion_estandar_fabrica2:.2f}')
plt.axvline(media2+desviacion_estandar_fabrica2,color='Black',linestyle='dashed',linewidth=2)
plt.xlabel('valor')
plt.ylabel('Frecuencia')
plt.title('Produccion diaria de la fabrica 2')
plt.legend()
plt.show()

# %%
import seaborn as sns

# %%
#La densidad grafica es una forma de visualizar la distribucion de datos en
#un intervalo o periodo de tiempo continuo.
#se basa en un histograma que usa el suavizado de kernel para trazar valores,
#lo que permite obtener distribuciones mas suaves al reducir el ruido.
#una curva de densidad muestra la ubicacion de la media y de la mediana de una distribucion
sns.histplot( x=fabrica1, kde=True, kde_kws={'bw_adjust':0.5}, bins=10)
# Out:
# <Axes: ylabel='Count'>

# %%
sns.histplot( x=fabrica2, kde=True, kde_kws={'bw_adjust':0.5}, bins=10)
# Out:
# <Axes: ylabel='Count'>
