# %% [markdown]
# <a href="https://colab.research.google.com/github/25041066NegreteSimentalJuanDiego/Probabilidad-y-Estadistica/blob/main/Unidad1/Practica3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #PROBABILIDAD Y ESTADISTICA
# ##Unidad 1
# ###Tabla de frecuencias y regla de Sturges.
# ###Facilitador: Jose Gabriel Rodriguez Rivas
# ###Negrete Simental Juan Diego

# %%
#Basado en el LIBRO estadistica para administracion pag 12
#Creamos una lista vacia que representa la edad de 100 personas
import random
edades = []
#Hacemos un ciclo para generar 100 numeros aleatorios que representan la edad de las personas
for i in range (100):
  #generamos un numero aleatorio con la funcion randint y la guaradmos en la variable
  #numero_aleatorio
  numero_aleatorio = random.randint(18,70)
  #Agregamos el numero aleatorio a la lista de valores
  edades.append (numero_aleatorio)
print(edades)
# Out:
# [41, 64, 50, 51, 46, 46, 44, 66, 39, 24, 29, 51, 63, 40, 31, 23, 28, 68, 60, 62, 68, 28, 69, 31, 40, 35, 45, 40, 62, 66, 20, 48, 52, 30, 27, 33, 53, 27, 30, 70, 32, 54, 70, 67, 57, 27, 27, 52, 21, 25, 53, 34, 27, 24, 67, 33, 39, 28, 61, 20, 70, 38, 66, 67, 64, 70, 62, 49, 67, 28, 30, 65, 65, 66, 53, 47, 36, 32, 64, 57, 21, 37, 38, 32, 20, 38, 51, 34, 38, 37, 31, 53, 61, 24, 37, 31, 53, 60, 19, 31]

# %%
import pandas as pd

# %%
#crear un dataframe de pandas con los numeros aleatorios
df = pd.DataFrame(edades, columns = ["Edad"])
df.head()
# Out:
#    Edad
# 0    41
# 1    64
# 2    50
# 3    51
# 4    46

# %%
#Calcular la tabla de distribucion de frecuencias
tabla_frecuencias=df["Edad"].value_counts().reset_index()
tabla_frecuencias.columns= ["Edad", "Frecuancia"]
tabla_frecuencias= tabla_frecuencias.sort_values(by='Edad')

#imprimir la tabla de distribucion de frecuencias
print("tabla de distribucion de frecuencias")
tabla_frecuencias
# Out:
# tabla de distribucion de frecuencias
#     Edad  Frecuancia
# 43    19           1
# 13    20           3
# 17    21           2
# 33    23           1
# 10    24           3
# 38    25           1
# 1     27           5
# 4     28           4
# 29    29           1
# 16    30           3
# 2     31           5
# 12    32           3
# 25    33           2
# 22    34           2
# 35    35           1
# 42    36           1
# 15    37           3
# 6     38           4
# 19    39           2
# 8     40           3
# 32    41           1
# 30    44           1
# 36    45           1
# 18    46           2
# 41    47           1
# 37    48           1
# 40    49           1
# 31    50           1
# 11    51           3
# 24    52           2
# 0     53           5
# 39    54           1
# 23    57           2
# 26    60           2
# 21    61           2
# 14    62           3
# 28    63           1
# 9     64           3
# 20    65           2
# 3     66           4
# 7     67           4
# 27    68           2
# 34    69           1
# 5     70           4

# %%
tabla_frecuencias["Frec Relativa"] = tabla_frecuencias["Frecuancia"] / 100
tabla_frecuencias
# Out:
#     Edad  Frecuancia  Frec Relativa
# 43    19           1           0.01
# 13    20           3           0.03
# 17    21           2           0.02
# 33    23           1           0.01
# 10    24           3           0.03
# 38    25           1           0.01
# 1     27           5           0.05
# 4     28           4           0.04
# 29    29           1           0.01
# 16    30           3           0.03
# 2     31           5           0.05
# 12    32           3           0.03
# 25    33           2           0.02
# 22    34           2           0.02
# 35    35           1           0.01
# 42    36           1           0.01
# 15    37           3           0.03
# 6     38           4           0.04
# 19    39           2           0.02
# 8     40           3           0.03
# 32    41           1           0.01
# 30    44           1           0.01
# 36    45           1           0.01
# 18    46           2           0.02
# 41    47           1           0.01
# 37    48           1           0.01
# 40    49           1           0.01
# 31    50           1           0.01
# 11    51           3           0.03
# 24    52           2           0.02
# 0     53           5           0.05
# 39    54           1           0.01
# 23    57           2           0.02
# 26    60           2           0.02
# 21    61           2           0.02
# 14    62           3           0.03
# 28    63           1           0.01
# 9     64           3           0.03
# 20    65           2           0.02
# 3     66           4           0.04
# 7     67           4           0.04
# 27    68           2           0.02
# 34    69           1           0.01
# 5     70           4           0.04

# %%
tabla_frecuencias["Frec Porcentual"] = tabla_frecuencias["Frecuancia"] / 100 * 100
tabla_frecuencias
# Out:
#     Edad  Frecuancia  Frec Relativa  Frec Porcentual
# 43    19           1           0.01              1.0
# 13    20           3           0.03              3.0
# 17    21           2           0.02              2.0
# 33    23           1           0.01              1.0
# 10    24           3           0.03              3.0
# 38    25           1           0.01              1.0
# 1     27           5           0.05              5.0
# 4     28           4           0.04              4.0
# 29    29           1           0.01              1.0
# 16    30           3           0.03              3.0
# 2     31           5           0.05              5.0
# 12    32           3           0.03              3.0
# 25    33           2           0.02              2.0
# 22    34           2           0.02              2.0
# 35    35           1           0.01              1.0
# 42    36           1           0.01              1.0
# 15    37           3           0.03              3.0
# 6     38           4           0.04              4.0
# 19    39           2           0.02              2.0
# 8     40           3           0.03              3.0
# 32    41           1           0.01              1.0
# 30    44           1           0.01              1.0
# 36    45           1           0.01              1.0
# 18    46           2           0.02              2.0
# 41    47           1           0.01              1.0
# 37    48           1           0.01              1.0
# 40    49           1           0.01              1.0
# 31    50           1           0.01              1.0
# 11    51           3           0.03              3.0
# 24    52           2           0.02              2.0
# 0     53           5           0.05              5.0
# 39    54           1           0.01              1.0
# 23    57           2           0.02              2.0
# 26    60           2           0.02              2.0
# 21    61           2           0.02              2.0
# 14    62           3           0.03              3.0
# 28    63           1           0.01              1.0
# 9     64           3           0.03              3.0
# 20    65           2           0.02              2.0
# 3     66           4           0.04              4.0
# 7     67           4           0.04              4.0
# 27    68           2           0.02              2.0
# 34    69           1           0.01              1.0
# 5     70           4           0.04              4.0

# %%
tabla_frecuencias["Frec Acumulada"] = tabla_frecuencias["Frecuancia"].cumsum()
tabla_frecuencias
# Out:
#     Edad  Frecuancia  Frec Relativa  Frec Porcentual  Frec Acumulada
# 43    19           1           0.01              1.0               1
# 13    20           3           0.03              3.0               4
# 17    21           2           0.02              2.0               6
# 33    23           1           0.01              1.0               7
# 10    24           3           0.03              3.0              10
# 38    25           1           0.01              1.0              11
# 1     27           5           0.05              5.0              16
# 4     28           4           0.04              4.0              20
# 29    29           1           0.01              1.0              21
# 16    30           3           0.03              3.0              24
# 2     31           5           0.05              5.0              29
# 12    32           3           0.03              3.0              32
# 25    33           2           0.02              2.0              34
# 22    34           2           0.02              2.0              36
# 35    35           1           0.01              1.0              37
# 42    36           1           0.01              1.0              38
# 15    37           3           0.03              3.0              41
# 6     38           4           0.04              4.0              45
# 19    39           2           0.02              2.0              47
# 8     40           3           0.03              3.0              50
# 32    41           1           0.01              1.0              51
# 30    44           1           0.01              1.0              52
# 36    45           1           0.01              1.0              53
# 18    46           2           0.02              2.0              55
# 41    47           1           0.01              1.0              56
# 37    48           1           0.01              1.0              57
# 40    49           1           0.01              1.0              58
# 31    50           1           0.01              1.0              59
# 11    51           3           0.03              3.0              62
# 24    52           2           0.02              2.0              64
# 0     53           5           0.05              5.0              69
# 39    54           1           0.01              1.0              70
# 23    57           2           0.02              2.0              72
# 26    60           2           0.02              2.0              74
# 21    61           2           0.02              2.0              76
# 14    62           3           0.03              3.0              79
# 28    63           1           0.01              1.0              80
# 9     64           3           0.03              3.0              83
# 20    65           2           0.02              2.0              85
# 3     66           4           0.04              4.0              89
# 7     67           4           0.04              4.0              93
# 27    68           2           0.02              2.0              95
# 34    69           1           0.01              1.0              96
# 5     70           4           0.04              4.0             100

# %% [markdown]
# ##Regla de Sturges
# #####1.Es una regla que sirve para calcular el numero de clases o intervalos idoneo en los que se debe dividir un conjunto de datos
# ######2.Establece que *El numero de clases es igual a uno mas el logaritmo en base dos del numero total de datos.
# ######c - 1 + log2 (N)
# ######Donde N es el tamaño de la muestra

# %%
#immportamos la libreria math de funciones matematicas.
import math

# %%
#Volvemos a usar la lista edades.
print(edades)
# Out:
# [41, 64, 50, 51, 46, 46, 44, 66, 39, 24, 29, 51, 63, 40, 31, 23, 28, 68, 60, 62, 68, 28, 69, 31, 40, 35, 45, 40, 62, 66, 20, 48, 52, 30, 27, 33, 53, 27, 30, 70, 32, 54, 70, 67, 57, 27, 27, 52, 21, 25, 53, 34, 27, 24, 67, 33, 39, 28, 61, 20, 70, 38, 66, 67, 64, 70, 62, 49, 67, 28, 30, 65, 65, 66, 53, 47, 36, 32, 64, 57, 21, 37, 38, 32, 20, 38, 51, 34, 38, 37, 31, 53, 61, 24, 37, 31, 53, 60, 19, 31]

# %%
#Crea un data frame con las edades
df = pd.DataFrame({'Edad': edades})
df
# Out:
#     Edad
# 0     41
# 1     64
# 2     50
# 3     51
# 4     46
# ..   ...
# 95    31
# 96    53
# 97    60
# 98    19
# 99    31
#
# [100 rows x 1 columns]

# %%
#Calcular el numero de intervalos utilizando la regla de Sturges
n=len(edades)
K=int(1+math.log2(n))
print("Valor de n = ", n ,"\n Numero de intervalos = ", K)
# Out:
# Valor de n =  100
#  Numero de intervalos =  7

# %%
#Crear la tabla de frecuencia
tabla_frecuencia = pd.cut( df["Edad"], bins=K, include_lowest=True).value_counts().reset_index()
tabla_frecuencia.columns=["Clase","Frec"]
tabla_frecuencia
# Out:
#               Clase  Frec
# 0  (26.286, 33.571]    23
# 1    (62.714, 70.0]    21
# 2  (33.571, 40.857]    16
# 3  (48.143, 55.429]    13
# 4  (18.948, 26.286]    11
# 5  (55.429, 62.714]     9
# 6  (40.857, 48.143]     7

# %%
#Ordenar la tabla de frecuencia por el intervalo
tabla_frecuencia = tabla_frecuencia.sort_values(by="Clase")
tabla_frecuencia
# Out:
#               Clase  Frec
# 4  (18.948, 26.286]    11
# 0  (26.286, 33.571]    23
# 2  (33.571, 40.857]    16
# 6  (40.857, 48.143]     7
# 3  (48.143, 55.429]    13
# 5  (55.429, 62.714]     9
# 1    (62.714, 70.0]    21

# %%
#Generar columnas siguientes
tabla_frecuencia ["Frec Rel"] = tabla_frecuencia ["Frec"] / n
tabla_frecuencia ["Frec Porc"] = tabla_frecuencia ["Frec"] / n * 100
tabla_frecuencia ["Frec Ac"] = tabla_frecuencia ["Frec"].cumsum()
tabla_frecuencia ["Frec rel AC"] = tabla_frecuencia ["Frec Rel"].cumsum()
tabla_frecuencia ["Frec Porc AC"] = tabla_frecuencia ["Frec Porc"].cumsum()
#Mostrar tabla de frecuencia
print(tabla_frecuencia)
# Out:
#               Clase  Frec  Frec Rel  Frec Porc  Frec Ac  Frec rel AC  \
# 4  (18.948, 26.286]    11      0.11       11.0       11         0.11
# 0  (26.286, 33.571]    23      0.23       23.0       34         0.34
# 2  (33.571, 40.857]    16      0.16       16.0       50         0.50
# 6  (40.857, 48.143]     7      0.07        7.0       57         0.57
# 3  (48.143, 55.429]    13      0.13       13.0       70         0.70
# 5  (55.429, 62.714]     9      0.09        9.0       79         0.79
# 1    (62.714, 70.0]    21      0.21       21.0      100         1.00
#
#    Frec Porc AC
# 4          11.0
# 0          34.0
# 2          50.0
# 6          57.0
# 3          70.0
# 5          79.0
# 1         100.0

# %%
import matplotlib.pyplot as plt

# %%
plt.hist(edades,alpha = 0.5)
plt.title("Histograma de edades basado en la funcion de matplotlib con valores estandar")
# Out:
# Text(0.5, 1.0, 'Histograma de edades basado en la funcion de matplotlib con valores estandar')

# %%
plt.hist(df["Edad"], bins=K, alpha = 0.5)
plt.title("Histograma de edades basado en la regla de Sturges")
plt.xlabel("Edades")
plt.xlabel("Frecuencia")
# Out:
# Text(0.5, 0, 'Frecuencia')
