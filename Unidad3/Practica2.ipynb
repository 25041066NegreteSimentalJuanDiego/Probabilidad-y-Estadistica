# %% [markdown]
# <a href="https://colab.research.google.com/github/25041066NegreteSimentalJuanDiego/Probabilidad-y-Estadistica/blob/main/Unidad3/Practica2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Probabilidad y Estadistica
# ##Unidad 3
# ###Practica 2: Valor esperado.
# ###Docente: Dr Jose Gabriel Rodriguez Rivas
# ###Alumno: Juan Diego Negrete Simental

# %%
import matplotlib.pyplot as plt

# %%
#Valores de la variable aleatoria
x=[5,6,7,8,9,10]
p=[0.05,0.10,0.20,0.30,0.25,0.10] #Probabilidades correspondientes

#Inicializar una variable para acumular la suma
valor_esperado=0

#recorrer los valores y sus probabilidades
for i in range(len(x)):
  xi=x[i]        #Valor de la variable aleatoria
  pi=p[i]        #Probabilidad de ese valor
  producto= xi * pi          #Multiplicar valor por su probabilidad
  valor_esperado += producto        #Sumar lo acumulado
  #Mostrar cada paso
  print(f"X = {xi}, p= {pi}, x*p = {producto:.2f}")
  #Mostrar resultado final
  print(f"\nValor esperado (Esperanza): {valor_esperado:.2f}")
# Out:
# X = 5, p= 0.05, x*p = 0.25
#
# Valor esperado (Esperanza): 0.25
# X = 6, p= 0.1, x*p = 0.60
#
# Valor esperado (Esperanza): 0.85
# X = 7, p= 0.2, x*p = 1.40
#
# Valor esperado (Esperanza): 2.25
# X = 8, p= 0.3, x*p = 2.40
#
# Valor esperado (Esperanza): 4.65
# X = 9, p= 0.25, x*p = 2.25
#
# Valor esperado (Esperanza): 6.90
# X = 10, p= 0.1, x*p = 1.00
#
# Valor esperado (Esperanza): 7.90
