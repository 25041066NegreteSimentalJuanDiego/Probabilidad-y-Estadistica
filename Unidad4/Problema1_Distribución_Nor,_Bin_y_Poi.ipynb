# %% [markdown]
# <a href="https://colab.research.google.com/github/25041066NegreteSimentalJuanDiego/Probabilidad-y-Estadistica/blob/main/Unidad4/Problema1_Distribuci%C3%B3n_Nor%2C_Bin_y_Poi.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Probabilidad y Estadistica
# ##Unidad 4
# ###EJERCICIO 1
# ###Docente: Dr Jose Gabriel Rodriguez Rivas
# ###Alumno: Juan Diego Negrete Simental

# %% [markdown]
# #Problema 1
#
# ##Antes de resolver el problema especifique si la solución es de tipo Binomial o Poisson y explique por qué.
#
# ##Realizar un programa en Python que resuelva el siguiente problema:
#
# ###• El número x de personas ingresadas a una unidad de cuidados intensivos en un hospital particular, en un día, tiene una distribución de probabilidad de Poisson con media igual a cinco personas por día.
# ###• a). ¿Cuál es la probabilidad de que el número de personas ingresadas a una unidad de cuidados intensivos en un hospital particular, en un día particular, sea dos?
# ###• b). ¿Es probable que x exceda de 10? Explicar.

# %% [markdown]
# ##Este problema es Poisson, no binomial.
# ##¿Por qué?
# ###Porque básicamente estamos contando cuántas personas llegan en un día, o sea en un tiempo fijo. Ya nos dicen que en promedio llegan 5 (λ = 5), pero no hay un número fijo de “intentos” como en la binomial. Entonces encaja mejor con Poisson, que justo sirve para este tipo de situaciones.

# %%
import math
from scipy.stats import poisson

# Parametro (media)
lam = 5

# a) Probabilidad de que X = 2
k = 2
p_a = (math.exp(-lam) * lam**k) / math.factorial(k)

# b) Probabilidad de que X > 10
# P(X > 10) = 1 - P(X <= 10)
p_b = 1 - poisson.cdf(10, lam)

# Resultados
print("a) Probabilidad de que X = 2:", p_a)


print("\nb) Probabilidad de que X > 10:", p_b)
# Out:
# a) Probabilidad de que X = 2: 0.08422433748856833
#
# b) Probabilidad de que X > 10: 0.013695268598382881
