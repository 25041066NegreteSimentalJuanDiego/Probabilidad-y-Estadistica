# %% [markdown]
# <a href="https://colab.research.google.com/github/25041066NegreteSimentalJuanDiego/Probabilidad-y-Estadistica/blob/main/Unidad4/Ejercicio_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Probabilidad y Estadistica
# ##Unidad 4
# ###Ejercicio 2
# ###Docente: Dr Jose Gabriel Rodriguez Rivas
# ###Alumno: Juan Diego Negrete Simental

# %% [markdown]
# #Ejercicio 2
# ###*Para una variable aleatoria binomial con n=10 y una probabilidad de 0.10.
# ###*Encontrar la probabilidad de la variable aletoria x=2. Realizar un prgrama en phyton que resuelva el problema usando una distribucion de probabilidad binomial.

# %%
from scipy.stats import binom

# Parámetros de la distribución binomial
n = 10
p = 0.10
x = 2

# Calcular la probabilidad de la variable aleatoria X = 2
probabilidad_x_2 = binom.pmf(x, n, p)

print("La probabilidad de que la variable aleatoria X sea igual a 2 es:", probabilidad_x_2)
